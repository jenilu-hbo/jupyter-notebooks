# %% [markdown]
# # 0 : Environment_Setup
#
# ### 0.1 : Load_packages

# %%
# !pip install urllib2 --user
# Out:
# ERROR: Could not find a version that satisfies the requirement urllib2 (from versions: none)
# ERROR: No matching distribution found for urllib2

# %%
# !pip install IMDbPY BeautifulSoup4  --user
# Out:
# Requirement already satisfied: IMDbPY in /home/ec2-user/.local/lib/python3.6/site-packages (2022.7.9)
# Requirement already satisfied: BeautifulSoup4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (4.9.3)
# Requirement already satisfied: cinemagoer in /home/ec2-user/.local/lib/python3.6/site-packages (from IMDbPY) (2022.2.11)
# Requirement already satisfied: soupsieve>1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from BeautifulSoup4) (2.0.1)
# Requirement already satisfied: lxml in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from cinemagoer->IMDbPY) (4.6.4)
# Requirement already satisfied: SQLAlchemy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from cinemagoer->IMDbPY) (1.3.23)

# %%
# general
import boto3
import datetime as dt
import json
import numpy as np
import pandas as pd
import snowflake.connector

from abc import ABCMeta, abstractmethod
from scipy.spatial.distance import squareform
#from scipy.cluster.hierarchy import ward
from scipy.cluster.hierarchy import  linkage
from scipy.cluster.hierarchy import fcluster

# %%
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### 0.2 : Connection to Snowflake

# %%
from abc import ABCMeta, abstractmethod

class Credentials(metaclass=ABCMeta):
    pass
    
    
class SSMPSCredentials(Credentials):
    def __init__(self, secretid: str):
        self._secretid = secretid
        self._secrets = {}
        
    def get_keys(self):
        """
        credential fetching 
        """
        _aws_sm_args = {'service_name': 'secretsmanager', 'region_name': 'us-east-1'}
        secrets_client = boto3.client(**_aws_sm_args)
        get_secret_value_response = secrets_client.get_secret_value(SecretId=self._secretid)
        return get_secret_value_response
    
    
class BaseConnector(metaclass=ABCMeta):
    @abstractmethod
    def connect(self):
        raise NotImplementedError
    

class SnowflakeConnector(BaseConnector):
    def __init__(self, credentials: Credentials):
        keys = credentials.get_keys()
        self._secrets = json.loads(keys.get('SecretString', "{}"))

    def connect(self, dbname: str, schema: str = 'DEFAULT'):
        ctx = snowflake.connector.connect(
            user=self._secrets['login_name'],
            password=self._secrets['login_password'],
            account=self._secrets['account'],
            warehouse=self._secrets['warehouse'],
            database=dbname,
            schema=schema
        )

        return ctx
    
## Credentials
SF_CREDS = 'datascience-max-dev-sagemaker-notebooks'

## Snowflake connection 
conn=SnowflakeConnector(SSMPSCredentials(SF_CREDS))
ctx=conn.connect("MAX_DEV","WORKSPACE")

def run_query(query):
    cursor = ctx.cursor()
    cursor.execute(query)
    df = pd.DataFrame(cursor.fetchall(), columns = [desc[0] for desc in cursor.description])
    df.columns= df.columns.str.upper()
    return df
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)

# %% [markdown]
# # 1 : Data Load

# %%
power_df=run_query('''
select distinct TITLE_ID, MAX(FIRST_VIEWS_7) AS  ACQUIRING_POWER
from max_dev.workspace.forecasting_fv_summary where country_iso_code = 'US'
GROUP BY 1
''')

# %%
input_master=run_query('''select * from  max_prod.DATASCIENCE.MAX_AUDIENCE_OVERLAP_FILTERED_ENDPOINT where dt = '2022-04-10' ''')

# input_june=run_query('''select * from  max_prod.DATASCIENCE.MAX_AUDIENCE_OVERLAP_FILTERED_ENDPOINT where dt = '2022-06-26' ''')

# input_may=run_query('''select * from  max_prod.DATASCIENCE.MAX_AUDIENCE_OVERLAP_FILTERED_ENDPOINT where dt = '2022-05-29' ''')

# input_april=run_query('''select * from  max_prod.DATASCIENCE.MAX_AUDIENCE_OVERLAP_FILTERED_ENDPOINT where dt = '2022-04-17' ''')

# input_index=run_query('''
# select * from max_prod.datascience_stage.AUDIENCE_OVERLAP_CONSOLIDATED_IDS 
# ''')

# %%
input_master.head()
# Out:
#       SCORE  INDEX_1 CONSOLIDATED_TITLE_1 LEVEL_1_CATG_NAME_1  \
# 0  1.000000        0             euphoria              series
# 1  0.795509        0             euphoria              series
# 2  0.842598        0             euphoria              series
# 3  0.666564        0             euphoria              series
# 4  0.206462        0             euphoria              series
#
#        CONSOLIDATED_ID_1  INDEX_2                CONSOLIDATED_TITLE_2  \
# 0  GXKN_xQX5csPDwwEAAABj        0                            euphoria
# 1  GXKN_xQX5csPDwwEAAABj        1                     game of thrones
# 2  GXKN_xQX5csPDwwEAAABj        2                             friends
# 3  GXKN_xQX5csPDwwEAAABj        3                          south park
# 4  GXKN_xQX5csPDwwEAAABj        4  last week tonight with john oliver
#
#   LEVEL_1_CATG_NAME_2      CONSOLIDATED_ID_2          DT
# 0              series  GXKN_xQX5csPDwwEAAABj  2022-04-10
# 1              series  GVU2cggagzYNJjhsJATwo  2022-04-10
# 2              series  GXdbR_gOXWJuAuwEAACVH  2022-04-10
# 3              series  GXr7SEgRi2sLCAAEAAAQu  2022-04-10
# 4              series  GVU2cCgUFTYNJjhsJATuH  2022-04-10

# %%
input_index=input_master.sort_values(by = ['INDEX_1'])[['INDEX_1','CONSOLIDATED_TITLE_1','LEVEL_1_CATG_NAME_1', 'CONSOLIDATED_ID_1']].drop_duplicates()

# %%
input_index=input_index.rename({'CONSOLIDATED_TITLE_1':'CONSOLIDATED_TITLE','LEVEL_1_CATG_NAME_1':'LEVEL_1_CATG_NAME','INDEX_1':'INDEX', 'CONSOLIDATED_ID_1':'CONSOLIDATED_ID'},axis=1)

# %%
input_index['CONSOLIDATED_TITLE']=input_index.CONSOLIDATED_TITLE.str.replace('$','')

# %%
input_index.head()
# Out:
#       INDEX                  CONSOLIDATED_TITLE LEVEL_1_CATG_NAME  \
# 0         0                            euphoria            series
# 1782      1                     game of thrones            series
# 2852      2                             friends            series
# 3927      3                          south park            series
# 4997      4  last week tonight with john oliver            series
#
#             CONSOLIDATED_ID
# 0     GXKN_xQX5csPDwwEAAABj
# 1782  GVU2cggagzYNJjhsJATwo
# 2852  GXdbR_gOXWJuAuwEAACVH
# 3927  GXr7SEgRi2sLCAAEAAAQu
# 4997  GVU2cCgUFTYNJjhsJATuH

# %%
input_index.shape
# Out:
# (1070, 4)

# %%
power_df.shape
# Out:
# (6232, 2)

# %%
power_df[power_df['TITLE_ID'] == 'GXKN_xQX5csPDwwEAAABj']
# Out:
#                   TITLE_ID  ACQUIRING_POWER
# 246  GXKN_xQX5csPDwwEAAABj         306205.0

# %%
# from sklearn.preprocessing import quantile_transform

# power_df['title']=power_df['INDEX'].str.lower()
# power_df['ACQUIRING_POWER_std']= quantile_transform(power_df['ACQUIRING_POWER'].values.reshape(-1, 1), n_quantiles=100, random_state=0, copy=True).ravel()
# power_df['RETENTION_POWER_std']= quantile_transform(power_df['RETENTION_POWER'].values.reshape(-1, 1), n_quantiles=100, random_state=0, copy=True).ravel()
all_index=input_index.merge(power_df.drop_duplicates(subset = ["TITLE_ID"]),left_on='CONSOLIDATED_ID',right_on='TITLE_ID',how='left')

# %% [markdown]
# # 2 : Data Processing

# %%
# Turn input row-based table into a pivoted, square matrix
audience_overlap = pd.pivot_table(
    input_master, 
    values='SCORE', 
    index=['INDEX_1'], 
    columns=['INDEX_2'], 
    aggfunc=np.sum
)
audience_overlap = audience_overlap.reset_index()
audience_overlap = audience_overlap.set_index('INDEX_1')

# %%
audience_overlap.iloc[0:3, 0:3]
# Out:
# INDEX_2         0         1         2
# INDEX_1
# 0        1.000000  0.795509  0.842598
# 1        0.795509  1.000000  0.822794
# 2        0.842598  0.822794  1.000000

# %%
audience_overlap.shape
# Out:
# (1070, 1070)

# %%
# Calculating the distance matrix from similarity score
# i.e., higher similarity = smaller distance

distance_matrix = 1 - audience_overlap.iloc[:, :]

# %%
# convert the redundant n*n square matrix form into a condensed nC2 array
# distance_matrix[{n choose 2}-{n-i choose 2} + (j-i-1)] is the distance between points i and j
distance_matrix = squareform(distance_matrix)

# %%
len(distance_matrix)
# Out:
# 571915

# %% [markdown]
# # 3 : Clustering

# %%
import matplotlib.pyplot as plt
from scipy.cluster import hierarchy

# %%
# Clusters have been defined by an elbow curve approach and also silhouette to confirm
z = linkage(distance_matrix, method='ward', optimal_ordering=True)

# %%
len(input_index)
# Out:
# 1070

# %%
number_of_clusters = 8

# %%
# Generating results for K number of clusters
clusters = fcluster(z, number_of_clusters, criterion='maxclust')

# %%
result = all_index.copy()
result['CLUSTER'] = clusters
result['title'] = result['CONSOLIDATED_TITLE']

# %%
# result.groupby('CLUSTER').agg({'ACQUIRING_POWER':'mean','RETENTION_POWER':'mean'})

# %%
# title_list=['cry macho', 'friends', 'sex and the city', 'south park', 'the big bang theory', 'sesame street', 'game of thrones', 'the matrix: resurrections'
#            , 'euphoria', 'search party']

# %%
result\
.sort_values(by=['CLUSTER','ACQUIRING_POWER'], ascending=False).groupby('CLUSTER').tail(5)
# Out:
#       INDEX                                 CONSOLIDATED_TITLE  \
# 1061   7167                                      moulin rouge!
# 1062   7186                                              julia
# 1065   7236                                         game night
# 1067   7285                                 jingle all the way
# 1069   7407                                           war dogs
# 986    3231                                   it's complicated
# 996    3405                                surviving christmas
# 1001   3525                                   just like heaven
# 1046   6892                               john tucker must die
# 1059   7124                                   the family stone
# 1049   7011                                      grandma's boy
# 1050   7022                                     mrs. doubtfire
# 1051   7047                     home alone 2: lost in new york
# 1052   7053                                  the suicide squad
# 1053   7067                                         unfriended
# 993    3355                                       the fugitive
# 1004   3590                                             wanted
# 1032   4708                                        constantine
# 1038   5408                                        constantine
# 1045   6777                                              shaft
# 912    2641                                         goodfellas
# 997    3430                                     public enemies
# 1028   4150                              24/7 college football
# 1037   5344                                           scarface
# 1048   6960                                friday night lights
# 909    2622                        elvis presley: the searcher
# 1031   4567  2018 rock and roll hall of fame induction cere...
# 1057   7107                                    teen titans go!
# 1063   7223                                                tag
# 1066   7256              music box: juice wrld: into the abyss
# 1029   4340                             scenes from a marriage
# 796    1983                               vice special reports
# 872    2384                                   jonah from tonga
# 921    2696                                   pod save america
# 1064   7232                                     it chapter two
# 902    2567                                      miss sherlock
# 617    1076                                     going in style
# 858    2298                                             grisse
# 1044   6686                                           animals.
# 1068   7399                                  life of the party
#
#      LEVEL_1_CATG_NAME        CONSOLIDATED_ID               TITLE_ID  \
# 1061             other  GVU3FdAjALINJjhsJAWsO                    NaN
# 1062             other  GVYEs8QbN7SzCKRAJACGM                    NaN
# 1065             other  GYK0FNAd52b2ElQEAAABP                    NaN
# 1067             other  GVU34KgxBJINJjhsJAaJ-                    NaN
# 1069             other  GYPm-KQYuU2yAwgEAAAA0                    NaN
# 986             movies  GWyku8grTIhnCwwEAAAB4                    NaN
# 996            unknown  GW3sshA73HcNOkQEAAAgu                    NaN
# 1001            movies  GXRtotQvV_G2YwgEAAABz                    NaN
# 1046             other  GVYERIAGgZCzCKRAJABKl                    NaN
# 1059             other  GVU4y1A5XNVFvjSoJAd0X                    NaN
# 1049             other  GVU4JwQXPlI7DwvwIAbgY                    NaN
# 1050             other  GVU2vfAjApY7DwvwIAVUq                    NaN
# 1051             other  GVU4apgYCvI7DwvwIAckI                    NaN
# 1052             other  GYTt7RAvZw7gTsAEAAAHi                    NaN
# 1053             other  GVkpg9gkOCpOtaqsKAAiN                    NaN
# 993            unknown  GWykvmQRfEIxamAEAAABx                    NaN
# 1004             other  GWZsKzgKRBrCCwwEAAAAU                    NaN
# 1032           unknown  GWHZQlwuQWqmywwEAAAEZ                    NaN
# 1038             other  GYSeWJgiWxqW8mwEAAAA6                    NaN
# 1045           unknown  GWPUgKQ34qoUfwwEAAAAl                    NaN
# 912            unknown  GW2nosAwYxsNOkQEAAAWG                    NaN
# 997             movies  GW3sskwnFUZFDwgEAAAf8                    NaN
# 1028           unknown  GXYUX5wrexKnCVgEAAAkr                    NaN
# 1037           unknown  GV2BxJwIRK6qSRQEAAAB7                    NaN
# 1048             other  GVpZInQtjjrKLw6EIAAAb                    NaN
# 909            unknown  GWnsFsAXWbRLDwwEAAAEv                    NaN
# 1031           special  GWsvH7gchY7LCwwEAAAA9                    NaN
# 1057             other  GYK0xWAMIRXXCMAEAAAB4                    NaN
# 1063             other  GYRaerQeoqDdFwwEAAAAj                    NaN
# 1066             other  GYbkACAXzIpyTwwEAAAHS                    NaN
# 1029            movies  GXnAoFgy1nZ4_wwEAAEnZ  GXnAoFgy1nZ4_wwEAAEnZ
# 796              other  GV-5wnQEOU6bCwwEAAAAW                    NaN
# 872             series  GVU20hwYR-YNJjhsJAVis                    NaN
# 921             series  GW6QT2QjwMAXCwgEAAAAd                    NaN
# 1064             other  GYGP7sgsEX4jDXAEAAAFs                    NaN
# 902             series  GW1XvdwD4PJFDwgEAAAMC  GW1XvdwD4PJFDwgEAAAMC
# 617             movies  GWeT0YgEJpbWurAEAAAIu  GWeT0YgEJpbWurAEAAAIu
# 858             series  GXGR8ggjVM4GmwwEAAAAC  GXGR8ggjVM4GmwwEAAAAC
# 1044             other               PMRS4885                    NaN
# 1068             other  GYPuuggkKbwqlwgEAAABC                    NaN
#
#       ACQUIRING_POWER  CLUSTER  \
# 1061              NaN        8
# 1062              NaN        8
# 1065              NaN        8
# 1067              NaN        8
# 1069              NaN        8
# 986               NaN        7
# 996               NaN        7
# 1001              NaN        7
# 1046              NaN        7
# 1059              NaN        7
# 1049              NaN        6
# 1050              NaN        6
# 1051              NaN        6
# 1052              NaN        6
# 1053              NaN        6
# 993               NaN        5
# 1004              NaN        5
# 1032              NaN        5
# 1038              NaN        5
# 1045              NaN        5
# 912               NaN        4
# 997               NaN        4
# 1028              NaN        4
# 1037              NaN        4
# 1048              NaN        4
# 909               NaN        3
# 1031              NaN        3
# 1057              NaN        3
# 1063              NaN        3
# 1066              NaN        3
# 1029              2.0        2
# 796               NaN        2
# 872               NaN        2
# 921               NaN        2
# 1064              NaN        2
# 902              55.0        1
# 617              50.0        1
# 858              28.0        1
# 1044              NaN        1
# 1068              NaN        1
#
#                                                   title
# 1061                                      moulin rouge!
# 1062                                              julia
# 1065                                         game night
# 1067                                 jingle all the way
# 1069                                           war dogs
# 986                                    it's complicated
# 996                                 surviving christmas
# 1001                                   just like heaven
# 1046                               john tucker must die
# 1059                                   the family stone
# 1049                                      grandma's boy
# 1050                                     mrs. doubtfire
# 1051                     home alone 2: lost in new york
# 1052                                  the suicide squad
# 1053                                         unfriended
# 993                                        the fugitive
# 1004                                             wanted
# 1032                                        constantine
# 1038                                        constantine
# 1045                                              shaft
# 912                                          goodfellas
# 997                                      public enemies
# 1028                              24/7 college football
# 1037                                           scarface
# 1048                                friday night lights
# 909                         elvis presley: the searcher
# 1031  2018 rock and roll hall of fame induction cere...
# 1057                                    teen titans go!
# 1063                                                tag
# 1066              music box: juice wrld: into the abyss
# 1029                             scenes from a marriage
# 796                                vice special reports
# 872                                    jonah from tonga
# 921                                    pod save america
# 1064                                     it chapter two
# 902                                       miss sherlock
# 617                                      going in style
# 858                                              grisse
# 1044                                           animals.
# 1068                                  life of the party

# %%
result[result['CONSOLIDATED_TITLE'].str.contains('suicide')]
# Out:
#       INDEX CONSOLIDATED_TITLE LEVEL_1_CATG_NAME        CONSOLIDATED_ID  \
# 10       10  the suicide squad            movies  GYOxtow3Wz8PDwgEAAAdw
# 49       49      suicide squad            movies  GXnEEogAPtp4_wwEAAEvU
# 1052   7053  the suicide squad             other  GYTt7RAvZw7gTsAEAAAHi
#
#                    TITLE_ID  ACQUIRING_POWER  CLUSTER              title
# 10    GYOxtow3Wz8PDwgEAAAdw         238977.0        8  the suicide squad
# 49    GXnEEogAPtp4_wwEAAEvU          11286.0        5      suicide squad
# 1052                    NaN              NaN        6  the suicide squad

# %% [markdown]
# # 4: Cluster Results Analysis

# %%
from bs4 import BeautifulSoup
import imdb
import urllib.request  as urllib2

# %%
def get_movie_id(name):
    ia = imdb.IMDb()
    # searching the name 
    search = ia.search_movie(name)
    # loop for printing the name and id
    for i in range(len(search)):
        # getting the id
        id = search[i].movieID
        # printing it
        print(search[i]['title'] + " : " + id )
        return id

# %%
from IPython.display import HTML, display,IFrame
import imdb
import urllib.request  as urllib2 

access = imdb.IMDb()
num_titles = 10

topmovies_df=result.drop_duplicates(subset='title').sort_values(by=['CLUSTER','ACQUIRING_POWER'], ascending=False).groupby('CLUSTER').head(10)
topmovies_df.head()
htmlstr=f'''<table>'''
n=num_titles
for index, row in topmovies_df.iterrows():    
    if (n>0):
        if (n==num_titles):
            htmlstr=htmlstr+'<tr>'
        try:
            movie_id=get_movie_id(row['title'])
            cluster_id=row['CLUSTER']
            movie = access.get_movie(movie_id)
            imgurl=movie['full-size cover url']
            htmlstr=htmlstr+f'''<td><img src={imgurl} width="120""></td>'''
        except:
            htmlstr=htmlstr+f'''<td>Missing</td>'''
        #print(row['title'], row['CLUSTER'])
        if (n==1):
            htmlstr=htmlstr+'</tr>'
            n=num_titles
        else:
            n=n-1  
htmlstr=htmlstr+'</table>'
# Out:
# The Suicide Squad : 6334354
# Dune : 1160419
# The Little Things : 10016180
# The Many Saints of Newark : 8110232
# King Richard : 9620288
# Cry Macho : 1924245
# Malignant : 3811906
# Those Who Wish Me Dead : 3215824
# Peacemaker : 13146488
# An American Pickle : 9059704
# Friends: The Reunion : 11337862
# Euphoria : 8772296
# And Just Like That... : 13819960
# Friends : 0108778
# In the Heights : 1321510
# Gossip Girl : 0397442
# The Fallout : 11847410
