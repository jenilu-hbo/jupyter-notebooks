# %%
# general
import boto3
import datetime as dt
import json
import numpy as np
import pandas as pd
import snowflake.connector

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
pd.options.display.float_format = '{:,.4f}'.format

# %%
# !pip install pygam

# %% [markdown]
# # 0. Read Data

# %%
import xgboost  
from xgboost import XGBRegressor
from sklearn.model_selection import GroupKFold

# %%
## WRITE OR READ FROM S3 ####
import boto3
import io

s3 = boto3.resource('s3')
output_bucket = "hbo-outbound-datascience-content-dev"
input_bucket = "hbo-ingest-datascience-content-dev"
bucket = s3.Bucket(input_bucket)

def write_to_sf(df, file_name):
    csv_buffer = io.StringIO()
    df.to_csv(csv_buffer, index = False)
    content = csv_buffer.getvalue()
    filename = 'title_hours_viewed_retention/{}.csv'.format(file_name)
    client = boto3.client('s3')
    client.put_object(Bucket=output_bucket, Key=filename, Body=content)
    
def write_to_input(df, file_name):
    csv_buffer = io.StringIO()
    df.to_csv(csv_buffer, index = False)
    content = csv_buffer.getvalue()
    filename = 'title_hours_viewed_retention/{}.csv'.format(file_name)
    client = boto3.client('s3')
    client.put_object(Bucket=input_bucket, Key=filename, Body=content)
    
def read_from_s3(filename, input_bucket = input_bucket):
    for obj in bucket.objects.filter(Prefix='title_hours_viewed_retention/'+filename): #churn_metric_0811
            key = obj.key 
            body = obj.get()['Body']
            print('Reading {0} features'.format(key))
            df = pd.read_csv(body, na_values = [r'\\\\N'])
    return df
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)

# %% [markdown]
# ## 0.1 Training Data

# %%
validation_data = read_from_s3('validation_data.csv')
# Out:
# Reading title_hours_viewed_retention/validation_data.csv features

# %%
manual_pop_title = ['Euphoria', 'House of the Dragon', 'Peacemaker', 'The Last of Us']

# %%
validation_data.loc[validation_data['title_name'].isin(manual_pop_title), 'medal_number'] = 0
validation_data['hit_series'] = 0
validation_data.loc[validation_data['title_name'].isin(manual_pop_title), 'hit_series'] = 1
validation_data.loc[(validation_data['title_name'] == 'Euphoria')&(validation_data['season_number'] == 1),
                   'hit_series'] = 0
validation_data.loc[(validation_data['title_name'] == 'Euphoria')&(validation_data['season_number'] == 1),
                   'medal_number'] = 3

# %%
validation_data.rename(columns = {'genre_Action/Adventure ':'genre_action', 'genre_Drama':'genre_drama',
                               'genre_Comedy':'genre_comedy', 'pillar_genre':'genre'}, inplace = True)

# %%
validation_data.loc[validation_data['genre'] == 'Action/Adventure ', 'genre'] = 'action'
validation_data.loc[validation_data['genre'] == 'Comedy', 'genre'] = 'comedy'
validation_data.loc[validation_data['genre'] == 'Drama', 'genre'] = 'drama'
validation_data.loc[~validation_data['genre'].isin(['action', 'comedy', 'drama']), 'genre'] = 'other'

validation_data.loc[validation_data['medal'] == 'None', 'medal'] = 'Bronze'
validation_data['medal_number'] = validation_data['medal_number'].fillna(3)

validation_data.loc[validation_data['content_category'] == 'special', 'content_category'] = 'movies'
validation_data = validation_data[validation_data['content_category'].isin(['movies', 'series'])]

validation_data = validation_data[validation_data['program_type'].notnull()]

# %%
validation_data[(validation_data['medal_number'] == 0)
               &()]
# Out:
#                                              title_name  \
# 1257                                   Raised by Wolves
# 1338                                   Charm City Kings
# 1454                           Roald Dahl’s The Witches
# 1467                               The Flight Attendant
# 1577                The Fresh Prince of Bel-Air Reunion
# 1683                                  Wonder Woman 1984
# 1794                                           Euphoria
# 4748                                           The Menu
# 4889                        Judas and the Black Messiah
# 4944                       Zack Snyder's Justice League
# 5117                                  Godzilla vs. Kong
# 5240                                      Mortal Kombat
# 5306                             Those Who Wish Me Dead
# 5448                               Friends: The Reunion
# 5466                                     In The Heights
# 5576             The Conjuring: The Devil Made Me Do It
# 5758                                  The Suicide Squad
# 5813                                       Reminiscence
# 5988                                          Malignant
# 6090                                               Dune
# 6224                                       King Richard
# 6329                              And Just Like That...
# 6395                                         Peacemaker
# 6448  Harry Potter 20th Anniversary: Return to Hogwarts
# 6569                                     The King's Man
# 6795                                         The Batman
# 6821        Fantastic Beasts: The Secrets of Dumbledore
# 7120                                House of the Dragon
# 7219                                              ELVIS
# 7384                                     The Last of Us
# 7409                                         Black Adam
#
#                    title_id  season_number  days_on_hbo_max  \
# 1257  GX0WFcAlf5r5cuAEAAADu              1               60
# 1338  GX3Oo8gHLjKHCwwEAAAEk              0               60
# 1454  GX5A8JQnSPQ2QFgEAAAAC              0               60
# 1467  GX5MHsQzwwIuLwgEAAACp              1               60
# 1577  GX7QU5AGnhiLDwwEAAAAj              0               60
# 1683  GX9KHPw1OIMPCJgEAAAAD              0               60
# 1794  GXKN_xQX5csPDwwEAAABj              2               60
# 4748  GY6HeoQwl0MPCLwEAAAgW              0               60
# 4889  GYBmsKA4FaUnDdQEAAAAj              0               60
# 4944  GYDAnZgCFQ8IJpQEAAAAN              0               60
# 5117  GYFEzmwNES16GkQEAAAAC              0               60
# 5240  GYGYKfQwaKLheqwEAAAEC              0               60
# 5306  GYH8W5wtYpsPDwgEAAAAC              0               60
# 5448  GYJxCDACcN8PDewEAAAAG              0               60
# 5466  GYK0x7gXCza4OwwEAAADl              0               60
# 5576  GYLEE7gB0zcLCwgEAAAHj              0               60
# 5758  GYOxtow3Wz8PDwgEAAAdw              0               60
# 5813  GYQBEaQwta8PCAAEAAAA-              0               60
# 5988  GYSaKIQwrHruinAEAAABN              0               60
# 6090  GYUjdLgBiJp5otAEAAAAJ              0               60
# 6224  GYXB0OgEQO5OhegEAAAAl              0               60
# 6329  GYYxBtQFFnmbDBwEAAAAE              1               60
# 6395  GYb0FKQLsGIyPfQEAAAAM              1               60
# 6448  GYbzrRAvf-ZPCKQEAAAAX              0               60
# 6569  GYeGXugg4ewPCwgEAABi1              0               60
# 6795  GYiDbSAmIpMNvYAEAAAAI              0               60
# 6821  GYij31wBohZA3MQEAAAKa              0               60
# 7120  GYsYeoAxKH8LCwgEAAAOR              1               60
# 7219  GYuwmqAnwQZa8kAEAAAE-              0               60
# 7384  GYyofRQHeuJ6fiQEAAAEy              1               60
# 7409  GYzcHIw5407mRsAEAAAA4              0               60
#
#       cumulative_hours_viewed  average_hours_viewed offering_start_date  \
# 1257           3,669,705.4175                1.1723          2020-09-03
# 1338             513,869.4014                0.1219          2020-10-08
# 1454           1,318,359.3806                0.2779          2020-10-22
# 1467           6,516,263.4670                0.9170          2020-11-26
# 1577             732,831.7744                0.1060          2020-11-19
# 1683          12,249,348.0638                1.5200          2020-12-25
# 1794          25,592,855.6164                1.8582          2022-01-10
# 4748           4,870,811.9097                0.4141          2023-01-03
# 4889           3,160,390.5814                0.2897          2021-02-12
# 4944          23,402,847.4237                1.9459          2021-03-18
# 5117          18,000,323.0330                1.4538          2021-03-31
# 5240          16,159,995.8810                1.2238          2021-04-23
# 5306           5,188,409.4082                0.3954          2021-05-14
# 1454        0.0000               1          0.0000   769,595.4774 0.1622
# 1467        0.0000               1          0.0000 1,135,842.8589 0.1598
# 1577        0.0000               1          0.0000   606,063.8278 0.0876
# 1683        0.0000               1          0.9829 4,965,393.6465 0.6162
# 1794        0.0000               1         -0.0164 3,272,978.0670 0.2376
# 4748        0.0000               1          0.1259 2,728,322.7811 0.2320
# 4889        0.0000               1          0.0000 1,533,137.1782 0.1405
# 4944        0.0000               1          0.0000 5,942,742.6543 0.4941
# 5117        0.0000               1          0.0000 9,677,593.0285 0.7816
# 5240        0.0000               1          0.0000 8,935,031.2925 0.6766
# 5306        0.0000               1          0.0000 3,166,883.2943 0.2414
# 5448        0.0000               1          0.0000 3,330,455.5283 0.2523
# 5466        0.0000               1          0.0000 1,350,052.8869 0.1023
# 5576        0.0000               1          0.0000 4,032,805.6975 0.3074
# 5758        0.0000               1          0.0000 6,937,785.0854 0.5252
# 5813        0.0000               1          0.0000 1,778,773.7129 0.1365
# 5988        0.0000               1          0.0000 2,043,116.0173 0.1572
# 6090        0.0000               1          0.0000 5,206,430.0061 0.4084
# 6224        0.0000               1          0.0000 2,154,918.2950 0.1591
# 6329        0.0000               1         -0.0958 1,741,328.4446 0.1271
# 6395        0.0000               1         -0.0767 2,177,199.5428 0.1582
# 6448        0.0000               1          0.0000 2,185,081.4328 0.1583
# 6569        0.0000               1          0.1588 2,129,371.6734 0.1600
# 6795        0.0000               1          0.1232 5,477,707.6555 0.4312
# 6821        0.0000               1          0.1232 2,700,964.9067 0.2203
# 7120        0.0000               1         -0.0548 4,162,758.3574 0.3421
# 7219        0.0000               1          0.2491 2,246,011.3975 0.1856
# 7384        0.0000               1         -0.1506 4,554,809.6003 0.3885
# 7409        0.0000               1          0.1533 3,699,152.9393 0.3128
#
#          content_cost  hit_series
# 1257  80,250,000.0000           0
# 1338   8,800,000.0000           0
# 1454  90,000,000.0000           0
# 1467  54,055,437.0000           0
# 1577   6,715,324.0000           0
# 1683  39,454,083.0000           0
# 1794 115,400,000.0000           1
# 4748   3,134,781.0000           0
# 4889  12,508,720.0000           0
# 4944  25,000,000.0000           0
# 5117  46,934,901.0000           0
# 5240  22,720,058.0000           0
# 5306  13,322,555.0000           0
# 5448  28,000,000.0000           0
# 5466  20,204,459.0000           0
# 5576              nan           0
# 5758  34,578,748.0000           0
# 5813  12,050,725.0000           0
# 5988  14,744,810.0000           0
# 6090  46,244,531.0000           0
# 6224  18,047,460.0000           0
# 6329 114,700,000.0000           0
# 6395 111,100,001.0000           1
# 6448   8,000,000.0000           0
# 6569   4,245,129.0000           0
# 6795  37,233,136.0000           0
# 6821  28,595,048.0000           0
# 7120 233,200,000.0000           1
# 7219   3,500,758.0000           0
# 7384 212,300,000.0000           1
# 7409  37,233,136.0000           0

# %% [markdown]
# ## 0.1 Testing Data

# %%
FEATURE_COLS = ['is_pay_1', 
                'hit_series',
                'medal_number', 
                'content_category_movies', 
                'content_category_series', 
                'program_type_acquired', 
                'program_type_original', 
                'genre_action', 
                'genre_comedy',
                'genre_drama'
#                 'age_of_content', 
#                 'budget', 
               ]
### New/Library content not able to be identified
### Budget data not able to be identified

# %%
# FEATURE_DICT = {
# 'is_pay_1': [0, 1] , 
# 'hit_series': [0, 1] ,
# 'medal_number': [0, 1, 2, 3]  , 
# 'content_category_movies': [0, 1] , 
# 'content_category_series': [0, 1] , 
# 'program_type_acquired': [0, 1] , 
# 'program_type_original': [0, 1] , 
# 'genre_action': [0, 1] , 
# 'genre_comedy': [0, 1] ,
# 'genre_drama' : [0, 1]    
# }

# %%
test_data = validation_data[FEATURE_COLS+['content_category', 'program_type', 'medal', 'genre']].drop_duplicates()

# %%
run_time = validation_data.groupby(['content_category'])['asset_run_time_hours'].mean().reset_index()

# %%
test_data = test_data.merge(run_time, on = ['content_category'])

# %% [markdown]
# # 1. Modeling - Scoring

# %%
META_COLS = ['asset_run_time_hours','content_category', 'program_type', 'medal', 'genre']

# %%
FEATURE_COLS = ['is_pay_1', 
                'hit_series',
                'medal_number', 
                'content_category_movies', 
                'content_category_series', 
                'program_type_acquired', 
                'program_type_original', 
                'genre_action', 
                'genre_comedy',
                'genre_drama'
#                 'age_of_content', 
#                 'budget', 
               ]
### New/Library content not able to be identified
### Budget data not able to be identified

# %%
def cal_error(validation_set):
    error_col = ((validation_set['pred']-validation_set[TARGET_COL[0]]).abs()/validation_set[TARGET_COL[0]]).abs()
    return error_col.mean()

# %% [markdown]
# ## 1.3 Log AVHR

# %%
# !pip install pygam

# %% [markdown]
# #### 1.3.1 Significant title classifier

# %%
training_data = validation_data.copy()

# %%
training_data['is_significant_title'] = 1
training_data.loc[training_data['ahvr'] < 0.01, 'is_significant_title'] = 0

# %%
training_data[FEATURE_COLS].isnull().sum()/len(training_data)
## Checking if there are any nulls in the feature columns
# Out:
# is_pay_1                  0.0000
# hit_series                0.0000
# medal_number              0.0000
# content_category_movies   0.0000
# content_category_series   0.0000
# program_type_acquired     0.0000
# program_type_original     0.0000
# genre_action              0.0000
# genre_comedy              0.0000
# genre_drama               0.0000
# dtype: float64

# %%
training_data['medal_number'] = training_data['medal_number'].fillna(3)

# %%
TARGET_COL = ['is_significant_title']

# %%
from sklearn.linear_model import LogisticRegression

# %%
## fit_predict prelaunch model|
X_train, X_test, y_train = training_data[FEATURE_COLS], test_data[FEATURE_COLS], training_data[TARGET_COL]

clf = LogisticRegression(random_state=0).fit(X_train, y_train)
print (clf.score(X_train, y_train))

pred = clf.predict(X_test)
pred = pd.DataFrame(pred)
pred.columns = ['sig_pred']
test_data.reset_index(inplace = True, drop = True)
test_data = pd.concat([test_data, pred], axis = 1)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 0.9083175803402647

# %%
# test_data[test_data['sig_pred'] == 0]

# %% [markdown]
# #### 1.3.2 Modeling

# %%
insig_title = test_data[test_data['sig_pred'] == 0]

# %%
len(insig_title)
# Out:
# 21

# %%
training_data = validation_data[(validation_data['ahvr']>0.01)]
# test_data = test_data[test_data['sig_pred'] == 1]

# %%
len(training_data)
# Out:
# 855

# %%
len(test_data)
# Out:
# 59

# %%
from pygam import LinearGAM, s, PoissonGAM

# %%
training_data['log_ahvr'] = np.log2(training_data['ahvr'])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
TARGET_COL = ['log_ahvr']

# %%
training_data[FEATURE_COLS].isnull().sum()/len(training_data)
# Out:
# is_pay_1                  0.0000
# hit_series                0.0000
# medal_number              0.0000
# content_category_movies   0.0000
# content_category_series   0.0000
# program_type_acquired     0.0000
# program_type_original     0.0000
# genre_action              0.0000
# genre_comedy              0.0000
# genre_drama               0.0000
# dtype: float64

# %%
training_data['medal_number'] = training_data['medal_number'].fillna(3)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
test_data[FEATURE_COLS].isnull().sum()/len(test_data)
# Out:
# is_pay_1                  0.0000
# hit_series                0.0000
# medal_number              0.0000
# content_category_movies   0.0000
# content_category_series   0.0000
# program_type_acquired     0.0000
# program_type_original     0.0000
# genre_action              0.0000
# genre_comedy              0.0000
# genre_drama               0.0000
# dtype: float64

# %%
X_train, X_test, y_train = training_data[FEATURE_COLS], test_data[FEATURE_COLS], training_data[TARGET_COL]
gam = LinearGAM(n_splines=20).fit(X_train, y_train)
pred = gam.predict(X_test)
pred = pd.DataFrame(pred)
pred.columns = ['logged_pred']
test_data.reset_index(inplace = True, drop = True)
test_data = pd.concat([test_data, pred], axis = 1)

# %%
test_data = test_data[META_COLS+FEATURE_COLS+['sig_pred']+['logged_pred']]

# %%
test_data['prediction'] = (2**(test_data['logged_pred']))

# %%
# insig_title = insig_title[META_COLS+FEATURE_COLS+['sig_pred']]

# insig_title['logged_pred']=0
# insig_title['prediction'] = np.NaN

# final_output =pd.concat([test_data, insig_title], axis = 0)

# %%
test_data[test_data['medal_number'] == 0]
# Out:
#     asset_run_time_hours content_category program_type     medal   genre  \
# 17                1.6303           movies     original  Platinum   other
# 22                1.6303           movies     original  Platinum   other
# 25                1.6303           movies     acquired  Platinum  action
# 35                1.6303           movies     acquired  Platinum  comedy
# 36                1.6303           movies     acquired  Platinum   drama
# 37                1.6303           movies     original  Platinum   drama
# 38                1.6303           movies     acquired  Platinum   other
# 51                6.7765           series     original  Platinum   other
# 55                6.7765           series     original  Platinum   drama
# 56                6.7765           series     original  Platinum   drama
# 58                6.7765           series     original  Platinum  comedy
#
#     is_pay_1  hit_series  medal_number  content_category_movies  \
# 17         0           0        0.0000                        1
# 22         0           0        0.0000                        0
# 25         1           0        0.0000                        1
# 35         1           0        0.0000                        1
# 36         1           0        0.0000                        1
# 37         0           0        0.0000                        1
# 38         1           0        0.0000                        1
# 51         0           0        0.0000                        0
# 55         0           0        0.0000                        0
# 56         0           1        0.0000                        0
# 58         0           0        0.0000                        0
#
#     content_category_series  program_type_acquired  program_type_original  \
# 17                        0                      0                      1
# 22                        0                      0                      1
# 25                        0                      1                      0
# 35                        0                      1                      0
# 36                        0                      1                      0
# 37                        0                      0                      1
# 38                        0                      1                      0
# 51                        1                      0                      1
# 55                        1                      0                      1
# 56                        1                      0                      1
# 58                        1                      0                      1
#
#     genre_action  genre_comedy  genre_drama  sig_pred  logged_pred  prediction
# 17             0             0            0         1      -2.7833      0.1453
# 22             0             0            0         1      -2.6322      0.1613
# 25             1             0            0         1      -1.7812      0.2909
# 35             0             1            0         1      -1.8642      0.2747
# 36             0             0            1         1      -2.1459      0.2260
# 37             0             0            1         1      -2.9073      0.1333
# 38             0             0            0         1      -2.0219      0.2462
# 51             0             0            0         1      -2.4968      0.1772
# 55             0             0            1         1      -2.6208      0.1626
# 56             0             0            1         1      -1.9112      0.2659
# 58             0             1            0         1      -2.3391      0.1976

# %% [markdown]
# # Write to S3/SF

# %%
len(test_data)
# Out:
# 59

# %% [markdown]
# #

# %%
write_to_input(test_data,'content_slate_metadata_level')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
