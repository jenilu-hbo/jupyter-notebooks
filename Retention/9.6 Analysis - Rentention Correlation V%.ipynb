# %%
# general
import boto3
import datetime as dt
import json
import numpy as np
import pandas as pd
import snowflake.connector

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
pd.options.display.float_format = '{:,.4f}'.format

# %%
from abc import ABCMeta, abstractmethod

class Credentials(metaclass=ABCMeta):
    pass
    
    
class SSMPSCredentials(Credentials):
    def __init__(self, secretid: str):
        self._secretid = secretid
        self._secrets = {}
        
    def get_keys(self):
        """
        credential fetching 
        """
        _aws_sm_args = {'service_name': 'secretsmanager', 'region_name': 'us-east-1'}
        secrets_client = boto3.client(**_aws_sm_args)
        get_secret_value_response = secrets_client.get_secret_value(SecretId=self._secretid)
        return get_secret_value_response
    
    
class BaseConnector(metaclass=ABCMeta):
    @abstractmethod
    def connect(self):
        raise NotImplementedError
    

class SnowflakeConnector(BaseConnector):
    def __init__(self, credentials: Credentials):
        keys = credentials.get_keys()
        self._secrets = json.loads(keys.get('SecretString', "{}"))

    def connect(self, dbname: str, schema: str = 'DEFAULT'):
        ctx = snowflake.connector.connect(
            user=self._secrets['login_name'],
            password=self._secrets['login_password'],
            account=self._secrets['account'],
            warehouse=self._secrets['warehouse'],
            database=dbname,
            schema=schema
        )

        return ctx
    
## Credentials
SF_CREDS = 'datascience-max-dev-sagemaker-notebooks'

## Snowflake connection 
conn=SnowflakeConnector(SSMPSCredentials(SF_CREDS))
ctx=conn.connect("MAX_DEV","WORKSPACE")

def run_query(query):
    cursor = ctx.cursor()
    cursor.execute(query)
    df = pd.DataFrame(cursor.fetchall(), columns = [desc[0] for desc in cursor.description])
    df.columns= df.columns.str.lower()
    return df
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning:
#
# Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/

# %%
hours_viewed = run_query('SELECT * FROM max_dev.workspace.user_title_hours_watched_crossvalidation')

# %%
hours_viewed.head()
# Out:
#                                       title_name               title_id  \
# 0                                             It  GWt7vKAJzFri8vQEAAAKm
# 1                    Snow White and the Huntsman  GX42eRA3gLmNViQEAAAYP
# 2  The Bee Gees: How Can You Mend A Broken Heart  GX5lfBgOJ7RKRwgEAAAMG
# 3                 Deathstroke: Knights & Dragons  GX9jvbw7CW3idqQEAAABV
# 4                                      Chernobyl  GXJvkMAU0JIG6gAEAAAIo
#
#    season_number offering_start_date    air_date  asset_run_time_hours  \
# 0              0          2020-10-27  2017-01-01                2.1964
# 1              0          2020-12-01  2012-06-01                2.0739
# 2              0          2020-12-13  2020-12-12                1.8503
# 3              0          2021-01-01  2020-08-18                1.4161
# 4              1          2020-05-27  2019-06-03                5.2950
#
#   content_category program_type   medal       pillar_genre  is_pay_1  \
# 0           movies     acquired    None            Horror          0
# 1           movies     acquired    None  Action/Adventure          0
# 2           movies     original  Silver        Documentary         0
# 3           movies     acquired    None  Action/Adventure          0
# 4           series     original    None              Drama         0
#
#    is_popcorn  medal_number  age_of_content  content_cost  \
# 0           0             4          3.8194       9029193
# 1           0             4          8.5012       3646400
# 2           0             2          0.0027       4500000
# 3           0             4          0.3724       1080000
# 4           0             4          0.9829      16200000
#
#    average_hours_viewed  log_average_hours_viewed  pred_logged  prediction  \
# 0                0.0585                   -4.0943      -4.1212      0.0575
# 1                0.0484                   -4.3680      -3.5002      0.0884
# 2                0.1034                   -3.2737      -3.5817      0.0835
# 3                0.0330                   -4.9221      -3.8342      0.0701
# 4                0.0394                   -4.6653      -3.9352      0.0654
#
#    pct_error
# 0     0.0185
# 1     0.8249
# 2     0.1922
# 3     1.1256
# 4     0.6588

# %%
vote_share = run_query('''SELECT *
                    FROM MAX_PROD.WORKSPACE.DAILY_CONTENT_VALUATION_METRICS_COMBINED 
                    where  1=1
                    -- AND days_on_hbo_max = 60
                    and region = 'NORTH AMERICA'
                    and LEGACY_HBOMAX_SERIES_VIEWABLE_ID = 'GV-54_wnG7qbCwwEAAAAY'
                    and REQUEST_DATE < '2020-07-01' and REQUEST_DATE >= '2020-06-01'
                    ORDER BY days_on_hbo_max
                    ''')

# %%
vote_share.head()
# Out:
#                 title_id  season_number         v_share
# 0  GX_Ob2gCXEKmohAEAAAAC         0.0000  0.000386498413
# 1  GYJLPwAnMvbSdwwEAAAD8         7.0000  0.000254930564
# 2  GXa5NxQH_E5GYoAEAAAAl         1.0000  0.000006679883
# 3  GYB3SAQKmr698pQEAAABL         1.0000  0.014606378387
# 4  GYGM-zQ4fFMJPwwEAAAAZ         0.0000  0.000122185640

# %%
hours_viewed_vs = hours_viewed.merge(vote_share, on = ['title_id', 'season_number'], how = 'left')

# %%
hours_viewed_vs[hours_viewed_vs['v_share'].isnull()]
# Out:
#                                              title_name  \
# 823                  Sherlock Holmes: A Game Of Shadows
# 844                                                 300
# 883                                       Green Lantern
# 884              Euphoria Special Episode Part 2: Jules
# 1107                                            Rampage
# 1116                                            Shazam!
# 1137                                      Dumb & Dumber
# 1154        Harry Potter: Hogwarts Tournament of Houses
# 1174                                     13 Going on 30
# 1178                                   Ready Player One
# 1183                                            Aquaman
# 1187                     Godzilla: King of the Monsters
# 1240                                       Little Nicky
# 1264                                    Nightmare Alley
# 1295                                      Ocean's Eight
# 1341                                        Point Break
# 1364             The Conjuring: The Devil Made Me Do It
# 1365                                  The Suicide Squad
# 1405                                     The Blind Side
# 1425               Euphoria Special Episode Part 1: Rue
# 1440                              The Dark Knight Rises
# 1442                 Batman v Superman: Dawn of Justice
# 1470                                The French Dispatch
# 1531                        Birds of Prey: Harley Quinn
# 1575                                  Crazy Rich Asians
# 1581  The Lord of the Rings: The Fellowship of the Ring
# 1613                                              Joker
# 1669                                            Dunkirk
# 1692                                          Long Shot
# 1726                                         Just Mercy
# 1744                                      The Last Duel
#
#                    title_id  season_number offering_start_date    air_date  \
# 823   GXoa09ws-QrDCYwEAAAMc              0          2020-06-01  2011-12-16
# 844   GYJWdJAUshsPCwgEAAABc              0          2022-01-01  2007-01-01
# 883   GXXAljgW4WcPCwgEAAAHP              0          2020-05-27  2011-06-17
# 884   GX_4Yaww4-L6pXwEAAAAE              0          2021-01-23  2021-01-22
# 1107  GX9q5dgUGL8ILwgEAAAFw              0          2021-01-01  2018-01-01
# 1116  GXXKT8Ae_jqnCVgEAAAOa              0          2020-05-27  2019-04-05
# 1137  GXtlhCgtvX5uSkwEAAATC              0          2020-07-01  1994-01-01
# 1154  GYZ9MrgqYWBq0wwEAAAAF              1          2022-01-01  2021-01-01
# 1174  GX4iIawx27GNViQEAAAOP              0          2020-11-01  2004-01-01
# 1178  GX9q5dgf0LMILwgEAAAF0              0          2021-01-01  2018-01-01
# 1183  GXPAj6wo7HoRYKAEAAAC7              0          2020-05-27  2018-12-21
# 1187  GXcWsXwq07ZuAuwEAAACT              0          2020-05-27  2019-05-31
# 1240  GXt52SQsDOpuSkwEAAAh-              0          2020-07-01  2020-07-01
# 1264  GYd9PZAt4esLDJwEAAAAK              0          2022-02-01  2021-12-03
# 1295  GX-N6ygNbA6qdwwEAAAAi              0          2021-01-01  2018-01-01
# 1341  GXx93XAnt5K0MlAEAAAFI              0          2020-09-01  1991-07-12
# 1364  GYLEE7gB0zcLCwgEAAAHj              0          2021-06-04  2021-06-04
# 1365  GYOxtow3Wz8PDwgEAAAdw              0          2021-08-05  2021-08-05
# 1405  GWykuVw3A54xamAEAAABW              0          2020-12-01  2009-01-01
# 1425  GX7WPJgqYpLZJwwEAAABu              0          2020-12-04  2020-12-04
# 1440  GXk3MQwDJOY7CZgEAACR5              0          2021-01-01  2012-01-01
# 1442  GXnEEqw6PJp4_wwEAAEv1              0          2020-05-27  2016-03-25
# 1470  GYdhCXgGwFIeXwgEAAAAC              0          2022-02-25  2021-10-22
# 1531  GXtq0PQyT7MPCwgEAAAaq              0          2020-08-16  2020-02-07
# 1575  GXGchGwJlJoGmwwEAAACR              0          2020-05-27  2018-08-15
# 1581  GXdu2ZAglVJuAuwEAADbA              0          2020-05-27  2001-12-19
# 1613  GXmpVdwe6e54_wwEAADHg              0          2020-05-27  2019-10-04
# 1669  GWqvX7wxdtyl0YAEAAAFv              0          2021-02-12  2017-01-01
# 1692  GXadU9ARQ58McQQEAAAKj              0          2020-05-27  2019-05-03
# 1726  GXxcJRAyVPMNqwwEAAAAL              0          2020-09-27  2019-12-25
# 1744  GYbzvWABDj8LDwgEAAAAp              0          2022-01-14  2021-10-15
#
#       asset_run_time_hours content_category program_type     medal  \
# 823                 2.1444           movies     acquired      None
# 844                 1.8839           movies     acquired      None
# 883                 1.9156           movies     acquired      None
# 884                 0.8053          special     original    Silver
# 1107                1.7383           movies     acquired      None
# 1116                2.1944           movies     acquired      None
# 1137                1.7386           movies     acquired      None
# 1154                2.8681           series     acquired      None
# 1174                1.6292           movies     acquired      None
# 1178                2.2603           movies     acquired      None
# 1183                2.3883           movies     acquired      None
# 1187                2.1944           movies     acquired      None
# 1240                1.5039           movies     acquired      None
# 1264                2.5017           movies     acquired    Silver
# 1295                1.7786           movies     acquired      None
# 1341                2.0322           movies     acquired      None
# 1364                1.8642           movies     acquired  Platinum
# 1365                2.1717           movies     acquired  Platinum
# 1405                2.0975           movies     acquired      None
# 1425                0.9283          special     original    Silver
# 1440                2.7414           movies     acquired      None
# 1442                2.5267           movies     acquired      None
# 1470                1.7931           movies     acquired    Silver
# 1531                1.8142           movies     acquired      Gold
# 1575                2.0097           movies     acquired      None
# 1581                2.8928           movies     acquired      None
# 1613                2.0292           movies     acquired      None
# 1669                1.7528           movies     acquired      None
# 1692                2.0383           movies     acquired      None
# 1726                2.2836           movies     acquired    Bronze
# 1744                2.5444           movies     acquired      Gold
#
#            pillar_genre  is_pay_1  is_popcorn  medal_number  age_of_content  \
# 823   Suspense/Thriller         0           0             4          8.4601
# 844   Action/Adventure          0           0             4         15.0010
# 883   Action/Adventure          0           0             4          8.9447
# 884               Other         0           0             2          0.0027
# 1107  Action/Adventure          0           0             4          3.0007
# 1116  Action/Adventure          1           0             4          1.1444
# 1137             Comedy         0           0             4         26.4975
# 1154         Unscripted         0           0             4          0.9993
# 1174               None         0           0             4         16.8354
# 1178  Action/Adventure          0           0             4          3.0007
# 1183  Action/Adventure          1           0             4          1.4319
# 1187  Action/Adventure          1           0             4          0.9911
# 1240               None         0           0             4          0.0000
# 1264  Action/Adventure          1           0             2          0.1643
# 1295  Action/Adventure          0           0             4          3.0007
# 1341  Action/Adventure          0           0             4         29.1423
# 1364            Horror          1           1             0          0.0000
# 1365  Action/Adventure          1           1             0          0.0000
# 1405              Drama         0           0             4         11.9154
# 1425              Other         0           0             2          0.0000
# 1440               None         0           0             4          9.0022
# 1442  Action/Adventure          0           0             4          4.1726
# 1470             Comedy         1           0             2          0.3450
# 1531  Action/Adventure          1           0             1          0.5229
# 1575            Romance         1           0             4          1.7824
# 1581  Action/Adventure          0           0             4         18.4371
# 1613  Action/Adventure          1           0             4          0.6461
# 1669  Action/Adventure          0           0             4          4.1151
# 1692             Comedy         1           0             4          1.0678
# 1726              Drama         1           0             3          0.7584
# 1744              Drama         1           0             1          0.2491
#
#       content_cost  average_hours_viewed  log_average_hours_viewed  \
# 823              0                0.0325                   -4.9452
# 844         990000                0.0670                   -3.8995
# 883          60000                0.0314                   -4.9951
# 884              0                0.1206                   -3.0515
# 1107       3367607                0.2054                   -2.2833
# 1116         40000                0.1036                   -3.2710
# 1137       3026250                0.0713                   -3.8095
# 1154             0                0.0837                   -3.5782
# 1174             0                0.0341                   -4.8755
# 1178       4819157                0.2841                   -1.8154
# 1183        533738                0.1230                   -3.0238
# 1187       4457767                0.0579                   -4.1113
# 1240             0                0.0863                   -3.5341
# 1264       1666226                0.1768                   -2.5000
# 1295             0                0.1548                   -2.6918
# 1341        567051                0.0575                   -4.1207
# 1364             0                0.1104                   -3.1789
# 1365      34578748                0.1040                   -3.2656
# 1405             0                0.0460                   -4.4408
# 1425      13100000                0.1876                   -2.4144
# 1440             0                0.1092                   -3.1944
# 1442       5600000                0.0401                   -4.6416
# 1470       3031658                0.0780                   -3.6795
# 1531             0                0.4859                   -1.0413
# 1575       5759586                0.0653                   -3.9377
# 1581       7548000                0.1319                   -2.9227
# 1613      13067037                0.1816                   -2.4608
# 1669       6430300                0.0890                   -3.4894
# 1692        941920                0.0535                   -4.2232
# 1726        133339                0.0518                   -4.2700
# 1744       2325555                0.4256                   -1.2326
#
#       pred_logged  prediction  pct_error v_share
# 823       -3.7901      0.0723     1.2271     NaN
# 844       -3.8662      0.0686     0.0233     NaN
# 883       -3.4407      0.0921     1.9372     NaN
# 884       -2.9842      0.1264     0.0478     NaN
# 1107      -3.5322      0.0864     0.5792     NaN
# 1116      -3.6815      0.0779     0.2476     NaN
# 1137      -4.1721      0.0555     0.2222     NaN
# 1154      -3.6856      0.0777     0.0717     NaN
# 1174      -4.2064      0.0542     0.5902     NaN
# 1178      -3.5544      0.0851     0.7004     NaN
# 1183      -3.7616      0.0737     0.4004     NaN
# 1187      -3.7891      0.0723     0.2502     NaN
# 1240      -4.1695      0.0556     0.3562     NaN
# 1264      -2.9372      0.1306     0.2615     NaN
# 1295      -3.4622      0.0907     0.4138     NaN
# 1341      -3.9223      0.0660     0.1475     NaN
# 1364      -3.0134      0.1238     0.1216     NaN
# 1365      -2.1492      0.2254     1.1681     NaN
# 1405      -3.9893      0.0630     0.3675     NaN
# 1425      -3.0001      0.1250     0.3337     NaN
# 1440      -3.7736      0.0731     0.3307     NaN
# 1442      -3.3775      0.0962     1.4018     NaN
# 1470      -3.1673      0.1113     0.4263     NaN
# 1531      -2.8739      0.1364     0.7192     NaN
# 1575      -3.9373      0.0653     0.0003     NaN
# 1581      -3.8976      0.0671     0.4912     NaN
# 1613      -3.7824      0.0727     0.5999     NaN
# 1669      -3.3419      0.0986     0.1076     NaN
# 1692      -3.9642      0.0641     0.1966     NaN
# 1726      -4.0333      0.0611     0.1782     NaN
# 1744      -3.1931      0.1093     0.7431     NaN

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
hours_viewed_vs.head()
# Out:
#                                       title_name               title_id  \
# 0                                             It  GWt7vKAJzFri8vQEAAAKm
# 1                    Snow White and the Huntsman  GX42eRA3gLmNViQEAAAYP
# 2  The Bee Gees: How Can You Mend A Broken Heart  GX5lfBgOJ7RKRwgEAAAMG
# 3                 Deathstroke: Knights & Dragons  GX9jvbw7CW3idqQEAAABV
# 4                                      Chernobyl  GXJvkMAU0JIG6gAEAAAIo
#
#    season_number offering_start_date    air_date  asset_run_time_hours  \
# 0              0          2020-10-27  2017-01-01                2.1964
# 1              0          2020-12-01  2012-06-01                2.0739
# 2              0          2020-12-13  2020-12-12                1.8503
# 3              0          2021-01-01  2020-08-18                1.4161
# 4              1          2020-05-27  2019-06-03                5.2950
#
#   content_category program_type   medal       pillar_genre  is_pay_1  \
# 0           movies     acquired    None            Horror          0
# 1           movies     acquired    None  Action/Adventure          0
# 2           movies     original  Silver        Documentary         0
# 3           movies     acquired    None  Action/Adventure          0
# 4           series     original    None              Drama         0
#
#    is_popcorn  medal_number  age_of_content  content_cost  \
# 0           0             4          3.8194       9029193
# 1           0             4          8.5012       3646400
# 2           0             2          0.0027       4500000
# 3           0             4          0.3724       1080000
# 4           0             4          0.9829      16200000
#
#    average_hours_viewed  log_average_hours_viewed  pred_logged  prediction  \
# 0                0.0585                   -4.0943      -4.1212      0.0575
# 1                0.0484                   -4.3680      -3.5002      0.0884
# 2                0.1034                   -3.2737      -3.5817      0.0835
# 3                0.0330                   -4.9221      -3.8342      0.0701
# 4                0.0394                   -4.6653      -3.9352      0.0654
#
#    pct_error         v_share
# 0     0.0185  0.002928350274
# 1     0.8249  0.001298312603
# 2     0.1922  0.004515435755
# 3     1.1256  0.000496565159
# 4     0.6588  0.002757910597

# %%
fig = px.scatter(hours_viewed_vs, x="v_share", y="average_hours_viewed", color='title_name')
fig.show()

# %%
hours_viewed_vs['tt_hours_viewed'] = hours_viewed_vs['average_hours_viewed']*hours_viewed_vs['asset_run_time_hours']

# %%
fig = px.scatter(hours_viewed_vs, x="v_share", y="tt_hours_viewed", color='title_name')
fig.show()

# %%
hours_viewed_vs['release_window'] = 'new_content'
hours_viewed_vs.loc[hours_viewed_vs['age_of_content'] > 1, 'release_window'] = 'library_content'

# %%
fig = px.scatter(hours_viewed_vs, x="v_share", y="tt_hours_viewed", color='release_window')
fig.show()

# %%
plot_df = hours_viewed_vs[hours_viewed_vs['content_category'] == 'series']
fig = px.scatter(plot_df, x="v_share", y="tt_hours_viewed", color='release_window')
fig.show()
#### Series

# %%
plot_df = hours_viewed_vs[hours_viewed_vs['content_category'] == 'movies']
fig = px.scatter(plot_df, x="v_share", y="tt_hours_viewed", color='release_window')
fig.show()

# %%
hours_viewed.head()
# Out:
#                                       title_name               title_id  \
# 0                                             It  GWt7vKAJzFri8vQEAAAKm
# 1                    Snow White and the Huntsman  GX42eRA3gLmNViQEAAAYP
# 2  The Bee Gees: How Can You Mend A Broken Heart  GX5lfBgOJ7RKRwgEAAAMG
# 3                 Deathstroke: Knights & Dragons  GX9jvbw7CW3idqQEAAABV
# 4                                      Chernobyl  GXJvkMAU0JIG6gAEAAAIo
#
#    season_number offering_start_date    air_date  asset_run_time_hours  \
# 0              0          2020-10-27  2017-01-01                2.1964
# 1              0          2020-12-01  2012-06-01                2.0739
# 2              0          2020-12-13  2020-12-12                1.8503
# 3              0          2021-01-01  2020-08-18                1.4161
# 4              1          2020-05-27  2019-06-03                5.2950
#
#   content_category program_type   medal       pillar_genre  is_pay_1  \
# 0           movies     acquired    None            Horror          0
# 1           movies     acquired    None  Action/Adventure          0
# 2           movies     original  Silver        Documentary         0
# 3           movies     acquired    None  Action/Adventure          0
# 4           series     original    None              Drama         0
#
#    is_popcorn  medal_number  age_of_content  content_cost  \
# 0           0             4          3.8194       9029193
# 1           0             4          8.5012       3646400
# 2           0             2          0.0027       4500000
# 3           0             4          0.3724       1080000
# 4           0             4          0.9829      16200000
#
#    average_hours_viewed  log_average_hours_viewed  pred_logged  prediction  \
# 0                0.0585                   -4.0943      -4.1212      0.0575
# 1                0.0484                   -4.3680      -3.5002      0.0884
# 2                0.1034                   -3.2737      -3.5817      0.0835
# 3                0.0330                   -4.9221      -3.8342      0.0701
# 4                0.0394                   -4.6653      -3.9352      0.0654
#
#    pct_error
# 0     0.0185
# 1     0.8249
# 2     0.1922
# 3     1.1256
# 4     0.6588

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
plot_df = plot_df[plot_df['days_on_hbo_max'] == 60]

# %%
plot_df = hours_viewed[hours_viewed['age_of_content']<20]
fig = px.histogram(plot_df, x="age_of_content", nbins=40)
fig.show()

# %%
plot_df = hours_viewed[hours_viewed['age_of_content']<20]
fig = px.histogram(plot_df, x="pillar_genre", nbins=20)
fig.show()
