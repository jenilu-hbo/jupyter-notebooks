# %%
# general
import boto3
import datetime as dt
import json
import numpy as np
import pandas as pd
import snowflake.connector

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %% [markdown]
# ### 0.2 : Connection to Snowflake

# %%
from abc import ABCMeta, abstractmethod

class Credentials(metaclass=ABCMeta):
    pass
    
    
class SSMPSCredentials(Credentials):
    def __init__(self, secretid: str):
        self._secretid = secretid
        self._secrets = {}
        
    def get_keys(self):
        """
        credential fetching 
        """
        _aws_sm_args = {'service_name': 'secretsmanager', 'region_name': 'us-east-1'}
        secrets_client = boto3.client(**_aws_sm_args)
        get_secret_value_response = secrets_client.get_secret_value(SecretId=self._secretid)
        return get_secret_value_response
    
    
class BaseConnector(metaclass=ABCMeta):
    @abstractmethod
    def connect(self):
        raise NotImplementedError
    

class SnowflakeConnector(BaseConnector):
    def __init__(self, credentials: Credentials):
        keys = credentials.get_keys()
        self._secrets = json.loads(keys.get('SecretString', "{}"))

    def connect(self, dbname: str, schema: str = 'DEFAULT'):
        ctx = snowflake.connector.connect(
            user=self._secrets['login_name'],
            password=self._secrets['login_password'],
            account=self._secrets['account'],
            warehouse=self._secrets['warehouse'],
            database=dbname,
            schema=schema
        )

        return ctx
    
## Credentials
SF_CREDS = 'datascience-max-dev-sagemaker-notebooks'

## Snowflake connection 
conn=SnowflakeConnector(SSMPSCredentials(SF_CREDS))
ctx=conn.connect("MAX_DEV","WORKSPACE")

def run_query(query):
    cursor = ctx.cursor()
    cursor.execute(query)
    df = pd.DataFrame(cursor.fetchall(), columns = [desc[0] for desc in cursor.description])
    df.columns= df.columns.str.lower()
    return df
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)

# %%
revenue = pd.read_csv('Revenue.csv', encoding = "ISO-8859-1")
revenue.head()
# Out:
#           Region Country   Company     Business Line Business model  \
# 0  North America     USA  Acorn TV  Subscription OTT   Subscription
# 1  North America     USA  Acorn TV  Subscription OTT   Subscription
# 2  North America     USA  Acorn TV  Subscription OTT   Subscription
# 3  North America     USA  Acorn TV  Subscription OTT   Subscription
# 4  North America     USA  Acorn TV  Subscription OTT   Subscription
#
#   Distribution/Technology Digital/Analogue  Year Quarter   Value
# 0                     OTT              NaN  2027      Q4  23,637
# 1                     OTT              NaN  2027      Q3  23,514
# 2                     OTT              NaN  2027      Q2  23,390
# 3                     OTT              NaN  2027      Q1  23,269
# 4                     OTT              NaN  2026      Q4  23,149

# %%
subscriber = pd.read_csv('Customers(RGUs).csv', encoding = "ISO-8859-1")
subscriber.head()
# Out:
#           Region Country   Company     Business Line Business model  \
# 0  North America     USA  Acorn TV  Subscription OTT   Subscription
# 1  North America     USA  Acorn TV  Subscription OTT   Subscription
# 2  North America     USA  Acorn TV  Subscription OTT   Subscription
# 3  North America     USA  Acorn TV  Subscription OTT   Subscription
# 4  North America     USA  Acorn TV  Subscription OTT   Subscription
#
#   Distribution/Technology Digital/Analogue  Year Quarter  Value
# 0                     OTT              NaN  2027      Q3  1,349
# 1                     OTT              NaN  2027      Q4  1,349
# 2                     OTT              NaN  2027      Q1  1,349
# 3                     OTT              NaN  2027      Q2  1,349
# 4                     OTT              NaN  2026      Q4  1,349

# %% [markdown]
# # AVOD/FAST

# %%
revenue_2022 = revenue[(revenue['Company'].isin(['PlutoTV', 'Tubi', 'Roku TV']))
                      &(revenue['Year'] == 2022)
                      &(revenue['Quarter'] == 'Q4')]

# %%
subscriber_2022 = subscriber[(subscriber['Company'].isin(['PlutoTV', 'Tubi', 'Roku TV']))
                      &(subscriber['Year'] == 2022)
                      &(subscriber['Quarter'] == 'Q4')]

# %%
revenue_2022['Value'] = revenue_2022['Value'].str.replace(',', '').astype(int)
subscriber_2022['Value'] = subscriber_2022['Value'].str.replace(',', '').astype(int)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
title_popularity = run_query('''
SELECT m.imdb_id, t.TITLE_TYPE, SUM(m.PAGE_VIEWS) AS total_page_views
FROM max_prod.ckg.wikipedia_page_views_media m
join "ENTERPRISE_DATA"."CATALOG"."IMDB_TITLE" t
ON m.imdb_id = t.title_id
WHERE m.DATE >= '2022-10-01'
AND m.DATE < '2023-01-01'
AND m.LANGUAGE = 'en'
GROUP BY 1, 2
''')

# %%
title_availabity = pd.read_csv('fast titles.csv', encoding= 'unicode_escape')

# %%
title_availabity = title_availabity.rename(columns = {'IMDb ID':'imdb_id', 'Platform':'platform', 'Title':'title', 'First Release Year':'production_release_date',
                                                     'Primary Genre':'primary_genre', 'Scripted':'scripted', 'Original':'is_original'})
title_availabity = title_availabity[title_availabity['platform'].isin(['Pluto TV (on-demand)', 'Tubi', 'Roku', ])]
title_availabity = title_availabity[['platform', 'title', 'imdb_id', 'production_release_date', 'primary_genre', 'scripted', 'is_original']]\
                    .drop_duplicates()

# %%
title_availabity.head()
# Out:
#                 platform                        title imdb_id  \
# 0   Pluto TV (on-demand)            ÁBoom! (Colombia)       -
# 3   Pluto TV (on-demand)  ÁBoom! (Colombia): Season 1       -
# 6   Pluto TV (on-demand)                Áboom! Mxico       -
# 9   Pluto TV (on-demand)      Áboom! Mxico: Season 1       -
# 12                  Tubi                 Áboom! Spain       -
#
#    production_release_date      primary_genre    scripted      is_original
# 0                     2017      Entertainment  Unscripted  Not An Original
# 3                     2017      Entertainment  Unscripted  Not An Original
# 6              [Not given]             Comedy  Unscripted  Not An Original
# 9              [Not given]             Comedy  Unscripted  Not An Original
# 12                    2015  Children & Family    Scripted  Not An Original

# %%
title_availabity_multiplatform = title_availabity.groupby(['imdb_id']).count().reset_index()
title_availabity_multiplatform =title_availabity_multiplatform[title_availabity_multiplatform['title']>1]

# %%
title_availabity_multiplatform
# Out:
#          imdb_id  platform  title  production_release_date  primary_genre  \
# 0              -     17552  17552                    17552          17552
# 31     tt0013427         2      2                        2              2
# 32     tt0013442         3      3                        3              3
# 33     tt0014142         3      3                        3              3
# 47     tt0016430         2      2                        2              2
# ...          ...       ...    ...                      ...            ...
# 39842  tt9896768         2      2                        2              2
# 39847  tt9903028         6      6                        6              6
# 39849  tt9904552         2      2                        2              2
# 39854  tt9906264         3      3                        3              3
# 39856  tt9912890         2      2                        2              2
#
#        scripted  is_original
# 0         17552        17552
# 31            2            2
# 32            3            3
# 33            3            3
# 47            2            2
# ...         ...          ...
# 39842         2            2
# 39847         6            6
# 39849         2            2
# 39854         3            3
# 39856         2            2
#
# [14606 rows x 7 columns]

# %%
title_popularity.head()
# Out:
#      imdb_id title_type  total_page_views
# 0  tt2886926      movie               120
# 1  tt0088031      movie             26737
# 2  tt0094056      movie             15968
# 3  tt0354318   tvSeries              6225
# 4  tt0043146      movie               398

# %% [markdown]
# ## Actual Revenues

# %%
title_availabity = title_availabity.merge(title_popularity, on = ['imdb_id'], how = 'left')

# %%
title_availabity.tail()
# Out:
#                    platform                  title    imdb_id  \
# 85036  Pluto TV (on-demand)                    ___          -
# 85037                  Tubi            ___________  tt0155658
# 85038                  Tubi  ___________: Season 1  tt0155658
# 85039  Pluto TV (on-demand)                 ___(_)  tt3963816
# 85040  Pluto TV (on-demand)                   ____  tt0079142
#
#       production_release_date      primary_genre  scripted      is_original  \
# 85036                    2009             Comedy  Scripted  Not An Original
# 85037                    1997  Children & Family  Scripted  Not An Original
# 85038                    1997  Children & Family  Scripted  Not An Original
# 85039                    2016   Crime & Thriller  Scripted  Not An Original
# 85040                    1979             Comedy  Scripted  Not An Original
#
#       title_type  total_page_views
# 85036        NaN               NaN
# 85037   tvSeries            8266.0
# 85038   tvSeries            8266.0
# 85039      movie           34712.0
# 85040      movie            5725.0

# %%
title_availabity=title_availabity[title_availabity['title_type'] == 'movie']

# %%
title_availabity.head()
# Out:
#                 platform                        title    imdb_id  \
# 28  Pluto TV (on-demand)  Àquin Diablos Es Juliette?  tt0126627
# 29                  Tubi  Àquin Diablos Es Juliette?  tt0126627
# 33                  Tubi       Àquin Te Quiere a Ti?  tt0180337
# 40  Pluto TV (on-demand)                          .45  tt0259822
# 41                  Roku                          .45  tt0259822
#
#    production_release_date     primary_genre    scripted      is_original  \
# 28                    1997     Entertainment  Unscripted  Not An Original
# 29                    1997     Entertainment  Unscripted  Not An Original
# 33                    1942            Comedy    Scripted  Not An Original
# 40                    2006  Crime & Thriller    Scripted  Not An Original
# 41                    2006  Crime & Thriller    Scripted  Not An Original
#
#    title_type  total_page_views
# 28      movie             257.0
# 29      movie             257.0
# 33      movie              43.0
# 40      movie            3582.0
# 41      movie            3582.0

# %%
title_availabity_sum = title_availabity.groupby(['platform']).sum().reset_index()

# %%
title_availabity_sum.rename(columns = {'total_page_views': 'platform_total_page_views'}, inplace = True)

# %%
title_availabity = title_availabity.merge(title_availabity_sum, on = ['platform'])

# %%
title_availabity.head()
# Out:
#                platform                        title    imdb_id  \
# 0  Pluto TV (on-demand)  Àquin Diablos Es Juliette?  tt0126627
# 1  Pluto TV (on-demand)                          .45  tt0259822
# 2  Pluto TV (on-demand)     'neath the Arizona Skies  tt0024805
# 3  Pluto TV (on-demand)                       1 Buck  tt4685428
# 4  Pluto TV (on-demand)                1 Mile to You  tt2184233
#
#   production_release_date       primary_genre    scripted      is_original  \
# 0                    1997       Entertainment  Unscripted  Not An Original
# 1                    2006    Crime & Thriller    Scripted  Not An Original
# 2                    1934  Action & Adventure    Scripted  Not An Original
# 3                    2017    Crime & Thriller    Scripted  Not An Original
# 4                    2017             Romance    Scripted  Not An Original
#
#   title_type  total_page_views  platform_total_page_views
# 0      movie             257.0                 80252968.0
# 1      movie            3582.0                 80252968.0
# 2      movie             710.0                 80252968.0
# 3      movie             133.0                 80252968.0
# 4      movie            3569.0                 80252968.0

# %%
title_availabity.platform.unique()
# Out:
# array(['Pluto TV (on-demand)', 'Tubi', 'Roku'], dtype=object)

# %%
revenue_2022 = revenue_2022[['Company', 'Value']].rename(columns= {'Company':'platform', 'Value':'Revenue'})
revenue_2022['platform']=revenue_2022['platform'].replace('PlutoTV','Pluto TV (on-demand)').replace('Roku TV','Roku')

# %%
revenue_2022.head()
# Out:
#                   platform  Revenue
# 5859  Pluto TV (on-demand)   223462
# 5942                  Roku   255558
# 6884                  Tubi   150496

# %%
title_availabity = title_availabity.merge(revenue_2022, on= ['platform'])

# %%
title_availabity.platform.unique()
# Out:
# array(['Pluto TV (on-demand)', 'Tubi', 'Roku'], dtype=object)

# %%
title_availabity['title_revenue'] = title_availabity['Revenue'] * title_availabity['total_page_views'] *1000 /title_availabity['platform_total_page_views']

# %%
title_availabity.head()
# Out:
#                platform                        title    imdb_id  \
# 0  Pluto TV (on-demand)  Àquin Diablos Es Juliette?  tt0126627
# 1  Pluto TV (on-demand)                          .45  tt0259822
# 2  Pluto TV (on-demand)     'neath the Arizona Skies  tt0024805
# 3  Pluto TV (on-demand)                       1 Buck  tt4685428
# 4  Pluto TV (on-demand)                1 Mile to You  tt2184233
#
#   production_release_date       primary_genre    scripted      is_original  \
# 0                    1997       Entertainment  Unscripted  Not An Original
# 1                    2006    Crime & Thriller    Scripted  Not An Original
# 2                    1934  Action & Adventure    Scripted  Not An Original
# 3                    2017    Crime & Thriller    Scripted  Not An Original
# 4                    2017             Romance    Scripted  Not An Original
#
#   title_type  total_page_views  platform_total_page_views  Revenue  \
# 0      movie             257.0                 80252968.0   223462
# 1      movie            3582.0                 80252968.0   223462
# 2      movie             710.0                 80252968.0   223462
# 3      movie             133.0                 80252968.0   223462
# 4      movie            3569.0                 80252968.0   223462
#
#    title_revenue
# 0     715.608848
# 1    9973.972352
# 2    1976.973861
# 3     370.334540
# 4    9937.774239

# %%
title_availabity.sort_values(by = ['title_revenue'], ascending = False).head(10)\
[['platform', 'title', 'production_release_date', 'primary_genre', 'scripted', 'is_original', 'title_revenue']]
# Out:
#                    platform                         title  \
# 17860                  Roku                     Terrifier
# 18793                  Roku  Weird: the Al Yankovic Story
# 17938                  Roku       The Blair Witch Project
# 2845   Pluto TV (on-demand)                 The Godfather
# 3300   Pluto TV (on-demand)                       Titanic
# 2695   Pluto TV (on-demand)       The Blair Witch Project
# 1324   Pluto TV (on-demand)                    Hereditary
# 16602                  Roku                     John Wick
# 1512   Pluto TV (on-demand)              Jeepers Creepers
# 1104   Pluto TV (on-demand)                  Forrest Gump
#
#       production_release_date     primary_genre  scripted      is_original  \
# 17860                    2018  Crime & Thriller  Scripted  Not An Original
# 18793                    2022            Comedy  Scripted    Roku Original
# 17938                    1999            Horror  Scripted  Not An Original
# 2845                     1972  Crime & Thriller  Scripted  Not An Original
# 3300                     1997           Romance  Scripted  Not An Original
# 2695                     1999            Horror  Scripted  Not An Original
# 1324                     2018            Horror  Scripted  Not An Original
# 16602                    2014  Crime & Thriller  Scripted  Not An Original
# 1512                     2001            Horror  Scripted  Not An Original
# 1104                     1994           Romance  Scripted  Not An Original
#
#        title_revenue
# 17860   6.105926e+06
# 18793   3.449668e+06
# 17938   3.324627e+06
# 2845    2.897367e+06
# 3300    2.744015e+06
# 2695    2.472905e+06
# 1324    2.229859e+06
# 16602   2.070000e+06
# 1512    1.971675e+06
# 1104    1.875989e+06

# %%
title_availabity.sort_values(by = ['title_revenue'], ascending = False).groupby(['platform']).first().reset_index()\
[['platform', 'title', 'production_release_date', 'primary_genre', 'scripted', 'is_original', 'title_revenue']]
# Out:
#                platform          title production_release_date  \
# 0  Pluto TV (on-demand)  The Godfather                    1972
# 1                  Roku      Terrifier                    2018
# 2                  Tubi      Terrifier                    2018
#
#       primary_genre  scripted      is_original  title_revenue
# 0  Crime & Thriller  Scripted  Not An Original   2.897367e+09
# 1  Crime & Thriller  Scripted  Not An Original   6.105926e+09
# 2  Crime & Thriller  Scripted  Not An Original   1.869951e+09

# %%
title_availabity[title_availabity['imdb_id'] == 'tt0133093']
# Out:
#       platform       title    imdb_id production_release_date  \
# 13024     Tubi  The Matrix  tt0133093                    1999
#
#           primary_genre  scripted      is_original title_type  \
# 13024  Sci-Fi & Fantasy  Scripted  Not An Original      movie
#
#        total_page_views  platform_total_page_views  Revenue  title_revenue
# 13024          537983.0                131270799.0   150496  616773.038519

# %% [markdown]
# ## HBO Titles

# %%
fast_titles = pd.read_csv('FAST Title Analysis - February Wiki Data.csv')

# %%
fast_titles.head()
# Out:
#               Title    imdb_id  PRODUCT ID  page_views
# 0       Matrix, The  tt0133093     2003656      117987
# 1  Edge of Tomorrow  tt1631867     2054390      105698
# 2     Departed, The  tt0407887     2025893      100895
# 3     Me Before You  tt2674426     2068798       87504
# 4     Notebook, The  tt0332280     2016856       87169

# %%
bbo_titles = title_availabity[title_availabity['imdb_id'].isin(fast_titles.imdb_id)]

# %%
bbo_titles
# Out:
#                    platform                                       title  \
# 109    Pluto TV (on-demand)                              A Star Is Born
# 683    Pluto TV (on-demand)                         Clash of the Titans
# 1860   Pluto TV (on-demand)                                    Mitchell
# 5429                   Tubi                          Cast a Dark Shadow
# 5747                   Tubi                                     Cop Out
# 6294                   Tubi                           Dog Day Afternoon
# 6871                   Tubi                                 Fit to Kill
# 7006                   Tubi                           Freddie Steps Out
# 7015                   Tubi                                  Free Willy
# 7184                   Tubi                  Ghosts of Girlfriends Past
# 7495                   Tubi                       Hard Ticket to Hawaii
# 7682                   Tubi                            High School Hero
# 109                   80252968.0   223462  870689.917537
# 683                   80252968.0   223462  489437.469627
# 1860                  80252968.0   223462   15893.756054
# 5429                 131270799.0   150496    7697.295603
# 5747                 131270799.0   150496   42070.294826
# 6294                 131270799.0   150496  137444.992256
# 6871                 131270799.0   150496    2294.055481
# 7006                 131270799.0   150496     350.815081
# 7015                 131270799.0   150496   79323.187787
# 7184                 131270799.0   150496   49658.677251
# 7495                 131270799.0   150496    6997.958350
# 7682                 131270799.0   150496     437.945624
# 8491                 131270799.0   150496   18886.691655
# 8940                 131270799.0   150496   38783.409736
# 9074                 131270799.0   150496    5079.939949
# 9301                 131270799.0   150496  223528.822309
# 9347                 131270799.0   150496    6543.962363
# 9446                 131270799.0   150496     332.471809
# 10523                131270799.0   150496   25662.237829
# 11396                131270799.0   150496   37289.579505
# 11590                131270799.0   150496   50252.540689
# 11894                131270799.0   150496   41340.003301
# 12275                131270799.0   150496   65060.147185
# 12926                131270799.0   150496   16408.056997
# 13016                131270799.0   150496  241990.179339
# 13024                131270799.0   150496  616773.038519
# 13097                131270799.0   150496     412.723625
# 13133                131270799.0   150496  370083.542129
# 13165                131270799.0   150496   84406.567100
# 13287                131270799.0   150496   37177.226963
# 13621                131270799.0   150496  234237.853919
# 13925                131270799.0   150496   31773.986841
# 14213                131270799.0   150496  131344.707790
# 14242                131270799.0   150496  194438.685484
# 14298                131270799.0   150496   90074.638214
# 14370                131270799.0   150496    3061.033551
# 14461                131270799.0   150496   99418.242499
# 14578                131270799.0   150496    1874.453130
# 15201                 68267082.0   255558  148714.384892
# 15605                 68267082.0   255558   29805.767822
# 15646                 68267082.0   255558  355228.450163
# 15928                 68267082.0   255558   21869.542278
# 16793                 68267082.0   255558   63018.123025
# 17008                 68267082.0   255558  328941.574799
# 17386                 68267082.0   255558   92445.797083
# 17883                 68267082.0   255558    5192.238127
# 18102                 68267082.0   255558  591282.494570
# 18621                 68267082.0   255558   61206.267759
# 18688                 68267082.0   255558  139400.550385
# 18712                 68267082.0   255558  634898.043540

# %% [markdown]
# ## Potentials

# %%
title_popularity = title_popularity[title_popularity['imdb_id'].isin(title_availabity.imdb_id)]

# %%
title_revenue = title_popularity.copy()
title_revenue['sum_page_views'] = title_popularity.total_page_views.sum()
title_revenue['revenue'] = revenue_2022.Value.sum()
# title_revenue['total_subs'] = subscriber_2022.Value.sum()

# %%
title_revenue['title_revenue'] = title_revenue['total_page_views']/title_revenue['sum_page_views'] * title_revenue['revenue']

# %%
# title_revenue['title_revenue_per_sub'] = title_revenue['title_revenue']/title_revenue['total_subs']

# %%
title_revenue.head()
# Out:
#       imdb_id  total_page_views  sum_page_views  revenue  title_revenue
# 20  tt2531334              7307       223244273   629516          20.60
# 27  tt2168288               990       223244273   629516           2.79
# 34  tt0385278              7936       223244273   629516          22.38
# 53  tt3993894              4883       223244273   629516          13.77
# 83  tt1950235             67065       223244273   629516         189.11

# %%
title_availabity = title_availabity.merge(title_revenue[['imdb_id', 'title_revenue',]],
                                          on = ['imdb_id'], how = 'left')

# %%
title_availabity.head()
# Out:
#                platform                        title imdb_id  \
# 0  Pluto TV (on-demand)            ÁBoom! (Colombia)       -
# 1  Pluto TV (on-demand)  ÁBoom! (Colombia): Season 1       -
# 2  Pluto TV (on-demand)                Áboom! Mxico       -
# 3  Pluto TV (on-demand)      Áboom! Mxico: Season 1       -
# 4                  Tubi                 Áboom! Spain       -
#
#   production_release_date      primary_genre    scripted      is_original  \
# 0                    2017      Entertainment  Unscripted  Not An Original
# 1                    2017      Entertainment  Unscripted  Not An Original
# 2             [Not given]             Comedy  Unscripted  Not An Original
# 3             [Not given]             Comedy  Unscripted  Not An Original
# 4                    2015  Children & Family    Scripted  Not An Original
#
#    title_revenue
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
title_availabity.sort_values(by = ['title_revenue'], ascending = False).groupby(['platform']).first().reset_index()\
[['platform', 'title', 'production_release_date', 'primary_genre', 'scripted', 'is_original', 'title_revenue']]
# Out:
#                platform          title production_release_date  \
# 0  Pluto TV (on-demand)  The Godfather                    1972
# 1                  Roku      Terrifier                    2018
# 2                  Tubi      Terrifier                    2018
#
#       primary_genre  scripted      is_original  title_revenue
# 0  Crime & Thriller  Scripted  Not An Original        2934.18
# 1  Crime & Thriller  Scripted  Not An Original        4599.39
# 2  Crime & Thriller  Scripted  Not An Original        4599.39

# %%
title_availabity.sort_values(by = ['title_revenue'], ascending = False).head(10)\
[['platform', 'title', 'production_release_date', 'primary_genre', 'scripted', 'is_original', 'title_revenue']]
# Out:
#                    platform                     title production_release_date  \
# 64960                  Roku                 Terrifier                    2018
# 64961                  Tubi                 Terrifier                    2018
# 69455  Pluto TV (on-demand)             The Godfather                    1972
# 66376                  Roku   The Blair Witch Project                    1999
# 66377                  Tubi   The Blair Witch Project                    1999
# 66375  Pluto TV (on-demand)   The Blair Witch Project                    1999
# 32293                  Tubi                Hellraiser                    1987
# 65316  Pluto TV (on-demand)  The Addams Family (1964)                    1964
# 65317                  Roku  The Addams Family (1964)                    1964
# 65318                  Tubi  The Addams Family (1964)                    1964
#
#           primary_genre  scripted      is_original  title_revenue
# 64960  Crime & Thriller  Scripted  Not An Original        4599.39
# 64961  Crime & Thriller  Scripted  Not An Original        4599.39
# 69455  Crime & Thriller  Scripted  Not An Original        2934.18
# 66376            Horror  Scripted  Not An Original        2504.33
# 66377            Horror  Scripted  Not An Original        2504.33
# 66375            Horror  Scripted  Not An Original        2504.33
# 32293  Crime & Thriller  Scripted  Not An Original        2410.62
# 65316            Horror  Scripted  Not An Original        2311.37
# 65317            Horror  Scripted  Not An Original        2311.37
# 65318            Horror  Scripted  Not An Original        2311.37

# %%
title_revenue_sub = title_availabity.groupby(['platform']).sum()[['title_revenue']].reset_index()\
                .merge(subscriber_2022.groupby(['Company']).sum()[['Value']],
                       left_on = ['platform'], right_on = ['Company'], how = 'left')
# title_revenue_sub['title_revenue_per_sub'] = title_revenue_sub['title_revenue']/title_revenue_sub['Value']

# %%
title_revenue_sub.rename(columns = {'Value':'Subscribers'})
# Out:
#                platform  title_revenue  Subscribers
# 0  Pluto TV (on-demand)      555759.93          NaN
# 1                  Roku      655894.04          NaN
# 2                  Tubi      663633.83          NaN
